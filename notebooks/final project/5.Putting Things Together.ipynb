# %% [markdown]
# # Putting things Together

# %% [markdown]
# ### Loading Pretrained Model
#
# Finally, We can load our trained model and use it to predict the gesture.

# %%
import sys
import torch

sys.path.append("../../") # we need to add the folder path to sys path to be able to import like below

from train import CNN

model = CNN()

# Model will have different state_dict() at this point
# print(new_model.state_dict())

checkpoint = torch.load('../../data/checkpoint.pth.tar')
model.load_state_dict(checkpoint['state_dict'])
print(model.state_dict())
# Out:
# OrderedDict([('conv1.0.weight', tensor([[[[ 0.1714,  0.1695, -0.1754,  0.1610,  0.1165],
#           [ 0.0948, -0.1709, -0.0858,  0.1308, -0.0206],
#           [-0.0683, -0.0954, -0.0405,  0.1121,  0.1950],
#           [-0.1576, -0.1964,  0.1961,  0.1877, -0.0082],
#           [-0.1260, -0.0954,  0.1295, -0.1168,  0.0749]]],
#
#
#         [[[ 0.0392,  0.0322, -0.1547,  0.2144,  0.0637],
#           [ 0.1612,  0.0127,  0.0175, -0.0431,  0.1231],
#           [-0.1211,  0.1276,  0.1531,  0.0741,  0.1507],
#           [ 0.0872, -0.2289, -0.2112, -0.1895,  0.0331],
#           [-0.0756,  0.1316, -0.1575,  0.0604, -0.0769]]],
#
#
#         [[[-0.0179,  0.1728, -0.1148,  0.0221,  0.1647],
#           [ 0.1089, -0.1034, -0.1346, -0.1794, -0.0760],
#           [ 0.1683, -0.0468,  0.0269, -0.2315, -0.1304],
#           [-0.1319,  0.1508,  0.0865,  0.1156,  0.0819],
#           [ 0.0154,  0.2225,  0.0591,  0.0113,  0.0834]]],
#
#
#         [[[ 0.1857,  0.2133, -0.1062,  0.1494,  0.0666],
#           [ 0.0713, -0.1152, -0.1240,  0.1191, -0.0823],
#           [-0.0328, -0.1875, -0.1426, -0.1951, -0.1337],
#           [ 0.0532,  0.0279, -0.2043, -0.0545,  0.1055],
#           [ 0.2255, -0.0366, -0.0427, -0.2054,  0.0081]]],
#
#
#         [[[ 0.1633, -0.0252, -0.0559, -0.1144, -0.1864],
#           [-0.1389, -0.0807, -0.1051, -0.2228,  0.1303],
#           [ 0.2063,  0.1923,  0.0623, -0.0343,  0.0131],
#           [-0.0617,  0.2321,  0.2079, -0.1256, -0.1994],
#           [ 0.1096,  0.1214,  0.1850,  0.1440, -0.1610]]],
#
#
#         [[[ 0.1623, -0.1000,  0.0593, -0.1975,  0.1121],
#           [-0.1906,  0.0783, -0.0266, -0.0406, -0.0645],
#           [ 0.1889, -0.0851,  0.1772, -0.2142, -0.0987],
#           [-0.0734,  0.1406,  0.2459,  0.0446,  0.1845],
#           [-0.0133,  0.1146, -0.0552, -0.0410, -0.0442]]],
#
#
#         [[[-0.1251,  0.0611,  0.0940, -0.1908,  0.0807],
#           [-0.0278, -0.1107,  0.0287, -0.0799,  0.0009],
#           [ 0.1659, -0.1603, -0.1715,  0.0249, -0.1145],
#           [ 0.0972,  0.1621, -0.0245, -0.0525, -0.1423],
#           [ 0.1504, -0.0553,  0.2349, -0.0811, -0.1319]]],
#
#
#         [[[-0.1204, -0.1111, -0.1184,  0.0507,  0.1239],
#           [ 0.1135, -0.0114,  0.1430, -0.1589, -0.1691],
#           [ 0.2084, -0.0903,  0.1751, -0.0188,  0.1173],
#           [-0.1077,  0.0499,  0.0394,  0.1150,  0.0982],
#           [ 0.2213, -0.0181,  0.1028,  0.2508,  0.0021]]],
#
#
#         [[[-0.1231, -0.1192, -0.1847,  0.1529, -0.0560],
#           [ 0.1909,  0.0911, -0.0866,  0.1125,  0.1117],
#           [ 0.1032, -0.0246, -0.0483,  0.1031, -0.0143],
#           [-0.1016,  0.0121,  0.0562,  0.0374,  0.1450],
#           [ 0.0396,  0.2151, -0.0913,  0.0512,  0.1176]]],
#
#
#         [[[ 0.0768, -0.1426, -0.0799, -0.1726, -0.0019],
#           [-0.0369,  0.1377,  0.1073, -0.0298, -0.1670],
#           [ 0.1564,  0.1155, -0.0305,  0.0299,  0.1662],
#           [-0.1234,  0.1653,  0.2073, -0.0914, -0.1886],
#           [ 0.1960, -0.1450,  0.0703, -0.2049, -0.0395]]],
#
#
#         [[[ 0.1529, -0.1779, -0.0991, -0.1321, -0.1322],
#           [ 0.1105, -0.0783, -0.1410,  0.0963, -0.1681],
#           [-0.1073, -0.0984,  0.1304, -0.0292,  0.1349],
#           [ 0.0514,  0.0481, -0.1579, -0.1936, -0.0055],
#           [ 0.0306, -0.1623, -0.0497,  0.0210, -0.0706]]],
#
#
#         [[[ 0.2223,  0.0246, -0.1219,  0.2453, -0.1339],
#           [ 0.0151, -0.0231, -0.1294, -0.0513,  0.0681],
#           [ 0.0536,  0.1319, -0.0505,  0.2076,  0.2367],
#           [-0.0185,  0.0506,  0.1763, -0.1055,  0.2801],
#           [-0.0195,  0.1759, -0.0868,  0.1099,  0.2611]]],
#
#
#         [[[ 0.0714, -0.0820, -0.0668, -0.0632,  0.0829],
#           [ 0.1793,  0.2783,  0.1717, -0.1622, -0.1164],
#           [ 0.0709, -0.1018, -0.0069, -0.0194, -0.1863],
#           [-0.2179, -0.1595,  0.1154, -0.0602,  0.1891],
#           [ 0.2419,  0.1417,  0.1765, -0.1214,  0.2598]]],
#
#
#         [[[ 0.2617,  0.0342,  0.1695, -0.0973, -0.0853],
#           [ 0.1537,  0.1076, -0.0612,  0.0950, -0.0364],
#           [ 0.2757, -0.0852, -0.0495, -0.1689, -0.2717],
#           [ 0.1079, -0.0900, -0.2458, -0.1758, -0.0157],
#           [ 0.1643, -0.1098, -0.3157, -0.1676, -0.0608]]],
#
#
#         [[[-0.1410,  0.0802,  0.2018,  0.0365,  0.3086],
#           [-0.1537,  0.1202,  0.2560,  0.0310,  0.2585],
#           [ 0.1476, -0.0968,  0.1477, -0.0645,  0.2919],
#           [-0.1897,  0.0337, -0.2003, -0.0088,  0.0459],
#           [-0.1513, -0.1283, -0.1382, -0.0465, -0.0944]]],
#
#
#         [[[ 0.2057,  0.0787,  0.3271, -0.2842, -0.2054],
#           [ 0.1057,  0.1021, -0.0109, -0.0065, -0.0491],
#           [ 0.1570,  0.1652,  0.0734, -0.0856, -0.1262],
#           [ 0.1165,  0.1960,  0.1211, -0.1651, -0.1466],
#           [-0.0881, -0.0368, -0.1571, -0.2854, -0.3145]]]])), ('conv1.0.bias', tensor([ 0.0018,  0.0750,  0.0892,  0.1950,  0.1224, -0.0132,  0.1663, -0.0574,
#           [-2.6710e-02, -6.8663e-02, -5.2263e-02,  8.6348e-03, -5.4520e-03],
#           [-5.1676e-02, -9.1540e-03,  9.0912e-03, -4.4769e-02, -1.3687e-02]],
#
#          [[-4.9798e-02,  1.1708e-02,  2.1137e-02, -1.6622e-02, -4.4064e-02],
#           [ 8.6500e-03, -4.8301e-02, -6.3300e-02, -2.5633e-02, -8.1373e-03],
#           [-6.9622e-02,  4.5601e-04,  2.7169e-02,  2.7788e-02, -6.5401e-02],
#           [-2.9878e-02,  2.4824e-02, -9.9154e-03,  1.6419e-02, -6.8897e-02],
#           [-6.2030e-02,  2.5106e-02,  4.1449e-03, -6.4727e-02, -5.5231e-02]],
#
#          ...,
#
#          [[-1.7740e-02, -2.7065e-02,  1.4841e-02,  4.3483e-02,  1.9426e-02],
#           [ 3.8112e-03,  1.4639e-02,  1.7147e-02,  3.5310e-02, -4.2554e-03],
#           [-4.9969e-02, -4.6779e-03, -1.6725e-02, -5.4171e-02, -6.4915e-03],
#           [-4.7587e-02,  2.9891e-02, -3.7212e-02, -1.2114e-02,  2.5789e-02],
#           [ 1.1785e-02, -3.9062e-02, -3.2114e-02, -2.0751e-02, -3.1507e-02]],
#
#          [[-3.1075e-02,  4.3195e-02,  2.2477e-02, -4.5456e-02, -3.3699e-02],
#           [ 3.2555e-02,  5.3330e-02, -2.5412e-02,  1.0003e-02, -2.3337e-02],
#           [ 3.3694e-02,  2.0294e-02, -3.0590e-02,  3.7210e-02,  4.5537e-02],
#           [-2.6102e-02,  2.9527e-02, -2.6425e-02, -2.4731e-02,  1.0525e-02],
#           [-2.0016e-02,  4.2176e-02, -1.7856e-03, -1.5663e-02, -2.9792e-03]],
#
#          [[ 3.7495e-02, -4.1298e-02, -2.5604e-02,  3.0582e-02,  2.4505e-02],
#           [ 1.0212e-02,  2.9548e-02, -3.3537e-02, -3.1765e-02,  4.1923e-02],
#           [-2.7670e-02,  3.5507e-02,  3.0472e-02, -3.4400e-02, -2.3903e-02],
#           [-4.3748e-02, -2.4683e-02,  2.8061e-02,  3.6111e-02, -2.2087e-02],
#           [ 3.9947e-02, -2.4222e-02, -2.5348e-02,  9.0291e-03, -3.2071e-03]]]])), ('conv2.0.bias', tensor([ 0.0240, -0.0615,  0.0128,  0.0218,  0.0116,  0.0204,  0.0447,  0.0091,
#         -0.0145,  0.0181,  0.0186, -0.0072, -0.0438, -0.0123, -0.0026,  0.0060,
#         -0.0017, -0.0011, -0.0441, -0.0104, -0.0142,  0.0324, -0.0439, -0.0194,
#         -0.0097, -0.0054,  0.0264, -0.0662, -0.0124,  0.0085, -0.0351, -0.0288])), ('out.weight', tensor([[-0.0045, -0.0413, -0.0336,  ..., -0.0008,  0.0188, -0.0189],
#         [ 0.0131, -0.0064,  0.0040,  ..., -0.0174, -0.0034,  0.0280]])), ('out.bias', tensor([-0.0196,  0.0188]))])

# %% [markdown]
# ### Detecting Gesture
# Now, we just get NAO's camera image feed and try to predict every image from the video stream to see if gesture is present.

# %%
import cv2
import numpy as np

from os.path import dirname, abspath
from vision_definitions import kQVGA,kBGRColorSpace
from naoqi import ALProxy
from torchvision import transforms
from torch.autograd import Variable

NAO_IP="192.168.1.7" # <YOUR_NAO_IP> or nao.local


if __name__=="__main__":  # Should not run when imported

    loader = transforms.Compose([
                        transforms.Grayscale(num_output_channels=1),
                        transforms.ToTensor()
                    ])
    
    camera_index = 0 # Top camera
    
    # Proxy for ALVideoDevice
    name = "nao_opencv"
    videoProxy = ALProxy("ALVideoDevice", NAO_IP, 9559)

    # Subscribe to video device on a specific camera
    # BGR for OpenCV
    name = videoProxy.subscribeCamera(name,camera_index,kQVGA,kBGRColorSpace,30)
    print "Subscribed to ", name

    try:
        frame = None
        # Keep Looping
        while True:
            # Get image
            img = videoProxy.getImageRemote(name)

            # Get image attributes
            width = img[0]
            height = img[1]
            nchannels = img[2]
            imgbuffer = img[6]
            
            # Get OpenCV image (allocate on first pass)
            if frame is None:
                print 'Grabbed image: ',width,'x',height,' nchannels=',nchannels
                frame=np.asarray(bytearray(imgbuffer), dtype=np.uint8)
                frame=frame.reshape((height,width,3))
            else:
                frame.data=bytearray(imgbuffer)

            # Display the frame to our screen
            # NOTE : Do not run this code if your run your python in the robot
            # as NAO has no screen to show
            cv2.imshow("Frame", frame)
            
            # Let's crop the image frame so the focus is in center
            upper_left = (80, 40)     #Crop: top left point
            bottom_right = (230, 190) #Crop: bottom right point
            cropped_frame = frame[upper_left[1] : bottom_right[1], upper_left[0] : bottom_right[0]]

            # Converting cropped color image to Grayscale
            gray_frame = cv2.cvtColor(cropped_frame, cv2.COLOR_BGR2GRAY)

            # Lets resize thee grayscale image to 28 x 28 (height x width) for convenience
            resized_frame = cv2.resize(gray_frame, dsize=(28, 28), interpolation=cv2.INTER_CUBIC)

            # Expanding the image to 1 x 28 x 28
            image = np.expand_dims(resized_frame, axis=0)
            
            image = torch.from_numpy(image).float()
            image = Variable(image)
            
            # Flatten the image to 1 x 1 x 28 x 28
            image = image.unsqueeze(0)
              
            # Prediction
            output, last_layer = model(image)
            pred = torch.max(output, 1)[1].data.squeeze()
            print(pred)
            
            if int(pred) == 0:
                # Left
                print('Left Hand Gesture Detected')
            elif int(pred) == 1:
                # Right
                print('Right Hand Gesture Detected')
                
            # Get the key pressed in the image window
            key = cv2.waitKey(33)&0xFF
            if  key == ord('q') or key == 27:
                # Exit loop when 'q' or 'Esc' is pressed on the image window
                break

    finally: # As fallback we'll make sure to unsubscribe
        print "Unsubscribing ",name
    
    cv2.destroyAllWindows()
    videoProxy.unsubscribe(name)
# Out:
# Subscribed to  nao_opencv_3
# Grabbed image:  320 x 240  nchannels= 3
# tensor(0)
# Left Hand Gesture Detected
# /home/rama/.local/lib/python2.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: Assigning the 'data' attribute is an inherently unsafe operation and will be removed in the future.
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(0)
# Left Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# tensor(1)
#  Hand Gesture Detected
# Unsubscribing  nao_opencv_3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-3d8d635a77f0> in <module>()
#      88
#      89             # Get the key pressed in the image window
# ---> 90             key = cv2.waitKey(33)&0xFF
#      91             if  key == ord('q') or key == 27:
#      92                 # Exit loop when 'q' or 'Esc' is pressed on the image window
#
# KeyboardInterrupt:

# %% [raw]
# ### Performing Gesture
#
# Now that we have detected the Gesture. We will make NAO do the custom commands for each gesture it detects.
#
# Let's say we want to make NAO move left if left hand signal is detected. We already know that we can make NAO move left with following commands using `ALMotion` Proxy as follows.

# %%
from naoqi import ALProxy

NAO_IP = "192.168.1.7"
NAO_PORT = 9559

motionProxy = ALProxy("ALMotion", NAO_IP, NAO_PORT)
    
motionProxy.moveInit()
motionProxy.moveTo(0, -0.5, 0) # To move left

# %% [markdown]
# ### Finally
#
# Now in order to do each action when each gesture is detected we can put things as follows.

# %%
import cv2
import numpy as np

from os.path import dirname, abspath
from vision_definitions import kQVGA,kBGRColorSpace
from naoqi import ALProxy
from torchvision import transforms
from torch.autograd import Variable


NAO_IP="192.168.1.7" # <YOUR_NAO_IP> or nao.local
NAO_PORT = 9559


if __name__=="__main__":  # Should not run when imported

    loader = transforms.Compose([
                        transforms.Grayscale(num_output_channels=1),
                        transforms.ToTensor()
                    ])
    
    camera_index = 0 # Top camera
    
    # Proxy for ALVideoDevice
    name = "nao_opencv"
    videoProxy = ALProxy("ALVideoDevice", NAO_IP, 9559)
    motionProxy = ALProxy("ALMotion", NAO_IP, NAO_PORT)
    
    motionProxy.moveInit()

    # Subscribe to video device on a specific camera
    # BGR for OpenCV
    name = videoProxy.subscribeCamera(name,camera_index,kQVGA,kBGRColorSpace,30)
    print "Subscribed to ", name

    try:
        frame = None
        # Keep Looping
        while True:
            # Get image
            img = videoProxy.getImageRemote(name)

            # Get image attributes
            width = img[0]
            height = img[1]
            nchannels = img[2]
            imgbuffer = img[6]
            
            # Get OpenCV image (allocate on first pass)
            if frame is None:
                print 'Grabbed image: ',width,'x',height,' nchannels=',nchannels
                frame=np.asarray(bytearray(imgbuffer), dtype=np.uint8)
                frame=frame.reshape((height,width,3))
            else:
                frame.data=bytearray(imgbuffer)

            # Display the frame to our screen
            # NOTE : Do not run this code if your run your python in the robot
            # as NAO has no screen to show
            cv2.imshow("Frame", frame)
            
            # Let's crop the image frame so the focus is in center
            upper_left = (80, 40)     #Crop: top left point
            bottom_right = (230, 190) #Crop: bottom right point
            cropped_frame = frame[upper_left[1] : bottom_right[1], upper_left[0] : bottom_right[0]]

            # Converting cropped color image to Grayscale
            gray_frame = cv2.cvtColor(cropped_frame, cv2.COLOR_BGR2GRAY)

            # Lets resize thee grayscale image to 28 x 28 (height x width) for convenience
            resized_frame = cv2.resize(gray_frame, dsize=(28, 28), interpolation=cv2.INTER_CUBIC)

            # Expanding the image to 1 x 28 x 28
            image = np.expand_dims(resized_frame, axis=0)
            
            image = torch.from_numpy(image).float()
            image = Variable(image)
            
            # Flatten the image to 1 x 1 x 28 x 28
            image = image.unsqueeze(0)
              
            # Prediction
            output, last_layer = model(image)
            pred = torch.max(output, 1)[1].data.squeeze()
            print(pred)
            
            if int(pred) == 0:
                # Left
                print('Left Hand Gesture Detected')
                motionProxy.moveTo(0, -0.5, 0) # To move left
            elif int(pred) == 1:
                # Right
                print('Right Hand Gesture Detected')
                motionProxy.moveTo(0, 0.5, 0) # To move right
                
            # Get the key pressed in the image window
            key = cv2.waitKey(33)&0xFF
            if  key == ord('q') or key == 27:
                # Exit loop when 'q' or 'Esc' is pressed on the image window
                break

    finally: # As fallback we'll make sure to unsubscribe
        print "Unsubscribing ",name
    
    cv2.destroyAllWindows()
    videoProxy.unsubscribe(name)
